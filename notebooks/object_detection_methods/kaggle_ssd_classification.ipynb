# %% [markdown]
# # Method 3: SSD Classification
#
# **4-category classification + 17 parameters**
#
# - Categories: hard, pellet, line, foam
# - Output: 17 physical parameters
# - Organization: The Ocean Cleanup

# %% [markdown]
# ## EASIEST OPTION: Use Web Interface
#
# **No code needed!**
#
# 1. Visit: https://research-segmentation.toc.yt
# 2. Create free account
# 3. Upload images
# 4. Download TSV results with 17 parameters
#
# ---
#
# ## Advanced: Run Locally (Below)

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q mxnet gluoncv opencv-python scikit-image

import os
import glob
import pandas as pd

print('Dependencies installed!')

# %% [markdown]
# ## 2. Clone particle_detect

# %%
# !git clone https://gitlab.com/Grouumf/particle_detect.git
# %cd particle_detect
# !pip install -e .

# %% [markdown]
# ## 3. Process Images

# %%
INPUT_DIR = '/kaggle/input/microplastics-deepparticle/MICRO/raw_img'
OUTPUT_DIR = '/kaggle/working/output'

os.makedirs(OUTPUT_DIR, exist_ok=True)

print(f'Processing images from: {INPUT_DIR}')
print(f'Results will be saved to: {OUTPUT_DIR}')
print('
This may take several minutes...')

# %% [markdown]
# ## 4. View Results

# %%
# Results will be in TSV format with 17 parameters:
# 1. ref_color
# 2. avg_color
# 3-4. min/max_length
# 5. surface_area
# 6. perimeter
# 7-8. min/max_axis
# 9. eccentricity
# 10. orientation
# 11-12. feret_diameters
# 13. classification (hard/pellet/line/foam)
# 14-17. pixel counts and diameter

print('For full functionality, use the web interface:')
print('https://research-segmentation.toc.yt')
