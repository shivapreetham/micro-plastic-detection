# %% [markdown]
# # Method 2: YOLOv5 Microplastic Detection
#
# **Fast object detection with bounding boxes**
#
# - Task: Detection + counting
# - Model: YOLOv5
# - Speed: Real-time
# - Paper: RSC Advances 2025

# %% [markdown]
# ## 1. Clone YOLOv5 and Install

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -qr requirements.txt

import torch
import os

print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')

# %% [markdown]
# ## 2. Dataset Configuration
#
# Update DATASET_PATH to your Kaggle dataset

# %%
DATASET_PATH = '/kaggle/input/microplastics-deepparticle'

# Create config
config = '''
path: {DATASET_PATH}
train: MICRO/raw_img
val: MICRO/raw_img

nc: 1
names: ['microplastic']
'''

with open('data/microplastic.yaml', 'w') as f:
    f.write(config.format(DATASET_PATH=DATASET_PATH))

# %% [markdown]
# ## 3. Train

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data data/microplastic.yaml --weights yolov5s.pt --project /kaggle/working/runs

# %% [markdown]
# ## 4. Inference

# %%
# !python detect.py --weights /kaggle/working/runs/train/exp/weights/best.pt --img 640 --source {DATASET_PATH}/MICRO/raw_img
